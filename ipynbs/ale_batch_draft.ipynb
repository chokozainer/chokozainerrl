# %%
import chokozainerrl
from pyvirtualdisplay import Display
display = Display(visible=0, size=(1024, 768))
display.start()
# %matplotlib inline
thisdir='../../draft/OpenAI/Breakout/result_double_iqn_ale_draft'

# %%
#@title Configuration
args=chokozainerrl.train_double_iqn_ale.make_args([])

args.mode = 'check' #@param ["check", "train"]
args.outdir=thisdir #@param{type:"string"}
args.gpu=-1 #@param{type:"integer"}
args.env = "BreakoutNoFrameskip-v4" #@param ["BreakoutNoFrameskip-v4","BreakoutNoFrameskip-v4"]{allow-input: true}
args.save_mp4=thisdir+'/pretrain.mp4'#@param{type:"string"}

# %%
from IPython.display import HTML
anim=chokozainerrl.train_double_iqn_ale.main(args)
HTML(anim.to_jshtml())
# Out:
# test episode: 0 R: 0.0
# test episode: 1 R: 0.0
# test episode: 2 R: 0.0
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Mircosoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img39afbcbbfd214270b422a1f224a1b6e3">
#   <div class="anim-controls">
#     <input id="_anim_slider39afbcbbfd214270b422a1f224a1b6e3" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim39afbcbbfd214270b422a1f224a1b6e3.set_frame(parseInt(this.value));"></input>
#     <div class="anim-buttons">
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.slower()"><i class="fa fa-minus"></i></button>
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.first_frame()"><i class="fa fa-fast-backward">
#           </i></button>
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.pause_animation()"><i class="fa fa-pause">
#           </i></button>
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.play_animation()"><i class="fa fa-play"></i>
#           </button>
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.next_frame()"><i class="fa fa-step-forward">
#           </i></button>
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.last_frame()"><i class="fa fa-fast-forward">
#           </i></button>
#       <button onclick="anim39afbcbbfd214270b422a1f224a1b6e3.faster()"><i class="fa fa-plus"></i></button>
#     </div>
#     <form action="#n" name="_anim_loop_select39afbcbbfd214270b422a1f224a1b6e3" class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_39afbcbbfd214270b422a1f224a1b6e3"
#              >
#       <label for="_anim_radio1_39afbcbbfd214270b422a1f224a1b6e3">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_39afbcbbfd214270b422a1f224a1b6e3"
#              checked>
#       <label for="_anim_radio2_39afbcbbfd214270b422a1f224a1b6e3">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_39afbcbbfd214270b422a1f224a1b6e3"
#              >
#       <label for="_anim_radio3_39afbcbbfd214270b422a1f224a1b6e3">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img39afbcbbfd214270b422a1f224a1b6e3";
#     var slider_id = "_anim_slider39afbcbbfd214270b422a1f224a1b6e3";
#     var loop_select_id = "_anim_loop_select39afbcbbfd214270b422a1f224a1b6e3";
#     var frames = new Array(600);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADh0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uMy4xLjEsIGh0\
# dHA6Ly9tYXRwbG90bGliLm9yZy8QZhcZAAADPklEQVR4nO3dMU4VURiAUcdQG1dgZeESiAsgr3Az\
# sAJXwDKMC7AgFJaGxRgLYywoGFsLiMDj3u85nNMyufcVX/47LzPAsq7r+gIiL+sPwPMmQFICJCVA\
# UgIkJUBSAiQlQFICJCVAUgIkJUBSAiQlQFICJCVAUgIkJUBSAiQlQFICJCVAUgIkJUBSR6MWXpZl\
# 1NIciKf4mwYmICkBkhIgqWH3gDOdn5//85qzs7Np1z/GjD1u2+up1nysTQT4t5mh3ef6x6ijmMkR\
# TGpzE3AL7pqsW5yMAjwQd8U16pg/FI5gUpubgA+dGKOvr9c9dMuovxHtUdz2eRTHf2/YEfxcjxQe\
# xgQkJUBSAiQlQFICJCVAUgIkJUBSAiQlQFLT34bZ4kuVWzfysaoJSEqApARISoCkBEhKgKQESEqA\
# pARISoCkBEhKgKQESEqApARIS

# %% [markdown]
# #学習の時間推定
# DQN (Deep Q Learning)
#
# 右のテーブルを変更すると、左に反映されます。
# 時間推定のために10000ステップくらいやってみます。

# %%
#@title Configuration
args=chokozainerrl.train_double_iqn_ale.make_args([])

args.mode = 'train' #@param ["check", "train"]
args.env = "BreakoutNoFrameskip-v4" #@param ["BreakoutNoFrameskip-v4","BreakoutNoFrameskip-v4"]{allow-input: true}
args.outdir=thisdir+'_precheck' #@param{type:"string"}
args.gpu=-1 #@param{type:"integer"}
args.log_type="pbar"#@param["pbar","full_stream"]{allow-input: true}

args.steps=10000 #@param{type:"integer"}
args.checkpoint_freq=10000 #@param{type:"integer"}
args.eval_interval=10000 #@param{type:"integer"}
args.eval_n_runs=1 #@param{type:"integer"}

# %% [markdown]
# ##Test Train
# 訓練開始です。

# %%
chokozainerrl.train_double_iqn_ale.main(args)
# Out:
# Start
# HBox(children=(IntProgress(value=0, max=10000), HTML(value='')))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-8069c6c8640e> in <module>
# ----> 1 chokozainerrl.train_double_iqn_ale.main(args)
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chokozainerrl/train_double_iqn_ale.py in main(args)
#     198             save_best_so_far_agent=True,
#     199             eval_env=eval_env,
# --> 200             log_type=args.log_type
#     201         )
#     202
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chokozainerrl/experiments/train_agent.py in train_agent_with_evaluation(agent, env, steps, eval_n_steps, eval_n_episodes, eval_interval, outdir, checkpoint_freq, train_max_episode_len, step_offset, eval_max_episode_len, eval_env, successful_score, step_hooks, save_best_so_far_agent, log_type, logger)
#     188         step_hooks=step_hooks,
#     189         logger=logger,
# --> 190         log_type=log_type
#     191         )
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chokozainerrl/experiments/train_agent.py in train_agent(agent, env, steps, outdir, checkpoint_freq, max_episode_len, step_offset, evaluator, successful_score, step_hooks, logger, log_type)
#      87                 if evaluator is not None:
#      88                     evaluator.evaluate_if_necessary(
# ---> 89                         t=t, episodes=episode_idx + 1)
#      90                     if (successful_score is not None and
#      91                             evaluator.max_score >= successful_score):
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chokozainerrl/experiments/evaluator.py in evaluate_if_necessary(self, t, episodes)
#     373     def evaluate_if_necessary(self, t, episodes):
#     374         if t >= self.prev_eval_t + self.eval_interval:
# --> 375             score = self.evaluate_and_update_max_score(t, episodes)
#     376             self.prev_eval_t = t - t % self.eval_interval
#     377             return score
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chokozainerrl/experiments/evaluator.py in evaluate_and_update_max_score(self, t, episodes)
#     344             self.env, self.agent, self.n_steps, self.n_episodes,
#     345             max_episode_len=self.max_episode_len,
# --> 346             logger=self.logger,log_type=self.log_type)
#     347         elapsed = time.time() - self.start_time
#     348         custom_values = tuple(tup[1] for tup in self.agent.get_statistics())
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chokozainerrl/experiments/evaluator.py in eval_performance(env, agent, n_steps, n_episodes, max_episode_len, logger, log_type)
#     263             env, agent, n_steps, n_episodes,
#     264             max_episode_len=max_episode_len,
# --> 265             logger=logger,log_type=log_type)
#     266     stats = dict(
#     267         episodes=len(scores),
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chokozainerrl/experiments/evaluator.py in run_evaluation_episodes(env, agent, n_steps, n_episodes, max_episode_len, logger, log_type)
#      67             episode_len = 0
#      68             info = {}
# ---> 69         a = agent.act(obs)
#      70         obs, r, done, info = env.step(a)
#      71         test_r += r
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainerrl/agents/dqn.py in act(self, obs)
#     363             action_value =\
#     364                 self._evaluate_model_and_update_recurrent_states(
# --> 365                     [obs], test=True)
#     366             q = float(action_value.max.array)
#     367             action = cuda.to_cpu(action_value.greedy_actions.array)[0]
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainerrl/agents/iqn.py in _evaluate_model_and_update_recurrent_states(self, batch_obs, test)
#     420                 0, 1,
#     421                 size=(len(batch_obs), self.quantile_thresholds_K)).astype('f')
# --> 422         return tau2av(taus_tilde)
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainerrl/agents/iqn.py in evaluate_with_quantile_thresholds(taus)
#     121         def evaluate_with_quantile_thresholds(taus):
#     122             return _evaluate_psi_x_with_quantile_thresholds(
# --> 123                 psi_x, self.phi, self.f, taus)
#     124
#     125         return evaluate_with_quantile_thresholds
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainerrl/agents/iqn.py in _evaluate_psi_x_with_quantile_thresholds(psi_x, phi, f, taus)
#      66     assert taus.shape[0] == batch_size
#      67     n_taus = taus.shape[1]
# ---> 68     phi_taus = phi(taus)
#      69     assert phi_taus.ndim == 3
#      70     assert phi_taus.shape == (batch_size, n_taus, hidden_size)
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainerrl/links/sequence.py in __call__(self, x, **kwargs)
#      38                 layer_kwargs = {k: v for k, v in kwargs.items()
#      39                                 if k in argnames}
# ---> 40             h = layer(h, **layer_kwargs)
#      41         return h
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainerrl/agents/iqn.py in __call__(self, x)
#      55         h = cosine_basis_functions(x, self.n_basis_functions)
#      56         h = F.reshape(h, (-1, self.n_basis_functions))
# ---> 57         out = self.linear(h)
#      58         out = F.reshape(out, x.shape + (self.out_size,))
#      59         return out
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainer/link.py in __call__(self, *args, **kwargs)
#     292             # forward is implemented in the child classes
#     293             forward = self.forward  # type: ignore
# --> 294         out = forward(*args, **kwargs)
#     295
#     296         # Call forward_postprocess hook
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainer/links/connection/linear.py in forward(self, x, n_batch_axes)
#     153             in_size = utils.size_of_shape(x.shape[n_batch_axes:])
#     154             self._initialize_params(in_size)
# --> 155         return linear.linear(x, self.W, self.b, n_batch_axes=n_batch_axes)
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainer/functions/connection/linear.py in linear(x, W, b, n_batch_axes)
#     306         args = x, W, b
#     307
# --> 308     y, = LinearFunction().apply(args)
#     309     if n_batch_axes > 1:
#     310         y = y.reshape(batch_shape + (-1,))
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainer/function_node.py in apply(self, inputs)
#     319             else:
#     320                 # In normal case, simply run the forward method.
# --> 321                 outputs = self.forward(in_data)
#     322
#     323         # Check for output array types
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainer/functions/connection/linear.py in forward(self, inputs)
#     114         # because it would break the model.
#     115         self.static_linear_no_bias(xp, x.dtype == W.dtype, inputs=[x, W],
# --> 116                                    outputs=[y])
#     117         if len(inputs) == 3:
#     118             self.static_add_bias(inputs=[b], outputs=[y])
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainer/graph_optimizations/static_graph_utilities.py in wrapped_func(*args, **kwargs)
#     182                         instance.schedule_func = schedule_function
#     183             else:
# --> 184                 ret = func(*args, **kwargs)
#     185             return ret
#     186         return wrapped_func
#
# ~/anaconda3/envs/chainer/lib/python3.7/site-packages/chainer/functions/connection/linear.py in static_linear_no_bias(self, xp, optimized, inputs, outputs)
#      54             # have the same dtype. Otherwise, the output type (for y)
#      55             # may not be as expected (i.e., not the same dtype as x).
# ---> 56             xp.dot(x, W.T, out=y)
#      57         else:
#      58             y[:] = x.dot(W.T).astype(x.dtype, copy=False)
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# KeyboardInterrupt:

# %% [markdown]
# #学習
# DQN (Deep Q Learning)
#
# 右のテーブルを変更すると、左に反映されます。

# %%
#@title Configuration
args=chokozainerrl.train_double_iqn_ale.make_args([])

args.mode = 'train' #@param ["check", "train"]
args.env = "BreakoutNoFrameskip-v4" #@param ["BreakoutNoFrameskip-v4","BreakoutNoFrameskip-v4"]{allow-input: true}
args.outdir=thisdir #@param{type:"string"}
args.gpu=0 #@param{type:"integer"}
args.load_agent=None #@param{type:"string"}
args.log_type="pbar"#@param["pbar","full_stream"]{allow-input: true}
args.arch='doubledqn'#@param['nature', 'nips', 'dueling', 'doubledqn']
args.agent='DoubleDQN'#@param['DQN', 'DoubleDQN', 'PAL']

args.steps=10000000 #@param{type:"integer"}
args.step_offset=0 #@param{type:"integer"}
args.checkpoint_frequency=500000 #@param{type:"integer"}
args.max_frames=30 * 60 * 60 #@param{type:"integer"}
args.eval_interval=100000 #@param{type:"integer"}
args.eval_n_runs=10 #@param{type:"integer"}

args.seed=0 #@param{type:"integer"}
args.final_exploration_frames=1000000 #@param{type:"integer"}
args.final_epsilon=0.01 #@param{type:"number"}
args.eval_epsilon=0.001 #@param{type:"number"}
args.noisy_net_sigma=None #@param{type:"number"}
args.replay_start_size=50000 #@param{type:"integer"}
args.target_update_interval=30000 #@param{type:"integer"}
args.update_interval=4 #@param{type:"integer"}
args.lr=2.5e-4 #@param{type:"number"}

# %% [markdown]
# ##Train
# 訓練開始です。

# %%
chokozainerrl.train_double_iqn_ale.main(args)

# %% [markdown]
# ##Result
# 学習結果の表です。

# %%
chokozainerrl.show_result.table(args.outdir+'/scores.txt')

# %% [markdown]
# 学習結果のグラフです。

# %%
chokozainerrl.show_result.graph(args.outdir+'/scores.txt','steps','average_q')

# %% [markdown]
# #学習後の表示

# %%
#@title Configuration
args=chokozainerrl.train_dqn_ale.make_args([])

args.mode = 'growth' #@param ["check", "train","growth"]
args.outdir=thisdir #@param{type:"string"}
args.env = "BreakoutNoFrameskip-v4" #@param ["BreakoutNoFrameskip-v4","Breakout-ram-v0"]{allow-input: true}
args.gpu=0 #@param{type:"integer"}
args.save_mp4=thisdir+'/posttrain.mp4'#@param{type:"string"}

# %% [markdown]
# ##Evaluation
# 学習済みのデータを用いて、３回試行した結果が表示されます。動画は、outdir+'/test.mp4'に出力されます。

# %%
from IPython.display import HTML
anim=chokozainerrl.train_dqn_ale.main(args)
HTML(anim.to_jshtml())
